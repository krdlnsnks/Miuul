# %% [markdown]
# <a href="https://colab.research.google.com/github/krdlnsnks/Miuul/blob/main/Kural_Tabanl%C4%B1_S%C4%B1n%C4%B1fland%C4%B1rma_ile_Potansiyel_M%C3%BC%C5%9Fteri_Getirisi_Hesaplamaipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##Başlangıçta gerekli importlar

# %%
import pandas as pd
pd.set_option("display.max_rows", None)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dd2e0a89-dc7f-40e9-a834-69c50776c088" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dd2e0a89-dc7f-40e9-a834-69c50776c088">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['persona.csv']))

# %%
print(df.head())
print(df.shape)
print(df.info())
# Out:
#    PRICE   SOURCE   SEX COUNTRY  AGE
# 0     39  android  male     bra   17
# 1     39  android  male     bra   17
# 2     49  android  male     bra   17
# 3     29  android  male     tur   17
# 4     49  android  male     tur   17
# (5000, 5)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 0 to 4999
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   PRICE    5000 non-null   int64
#  1   SOURCE   5000 non-null   object
#  2   SEX      5000 non-null   object
#  3   COUNTRY  5000 non-null   object
#  4   AGE      5000 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 234.4+ KB
# None

# %%
df["SOURCE"].nunique()
df["SOURCE"].value_counts() #Kaç unique SOURCE vardır? Frekansları nedir?
# Out:
# android    2974
# ios        2026
# Name: SOURCE, dtype: int64

# %%
df["PRICE"].nunique() #Kaç unique PRICE vardır?
# Out:
# 6

# %%
df["PRICE"].value_counts() #Hangi PRICE'dan kaçar tane satış gerçekleşmiş?
# Out:
# 29    1305
# 39    1260
# 49    1031
# 19     992
# 59     212
# 9      200
# Name: PRICE, dtype: int64

# %%
df["COUNTRY"].value_counts()
df.groupby("COUNTRY")["PRICE"].count() #Hangi ülkeden kaçar tane satış olmuş?
# Out:
# COUNTRY
# bra    1496
# can     230
# deu     455
# fra     303
# tur     451
# usa    2065
# Name: PRICE, dtype: int64

# %%
df.pivot_table(values="PRICE",index="COUNTRY",aggfunc="count")
# Out:
#          PRICE
# COUNTRY
# bra       1496
# can        230
# deu        455
# fra        303
# tur        451
# usa       2065

# %%
df.groupby("COUNTRY")["PRICE"].sum()
df.groupby("COUNTRY").agg({"PRICE": "sum"})
df.pivot_table(values="PRICE",index="COUNTRY",aggfunc="sum")
 #Ülkelere göre satışlardan toplam ne kadar kazanılmış?
# Out:
#          PRICE
# COUNTRY
# bra      51354
# can       7730
# deu      15485
# fra      10177
# tur      15689
# usa      70225

# %%
df["SOURCE"].value_counts() #SOURCE türlerine göre göre satış sayıları nedir?
# Out:
# android    2974
# ios        2026
# Name: SOURCE, dtype: int64

# %%
#Ülkelere göre PRICE ortalamaları nedir?
df.groupby(by=['COUNTRY']).agg({"PRICE": "mean"})
# Out:
#              PRICE
# COUNTRY
# bra      34.327540
# can      33.608696
# deu      34.032967
# fra      33.587459
# tur      34.787140
# usa      34.007264

# %%
#SOURCE'lara göre PRICE ortalamaları nedir?
df.groupby(by=['SOURCE']).agg({"PRICE": "mean"})
# Out:
#              PRICE
# SOURCE
# android  34.174849
# ios      34.069102

# %%
#COUNTRY-SOURCE kırılımında PRICE ortalamaları nedir?
df.groupby(by=["COUNTRY", 'SOURCE']).agg({"PRICE": "mean"})
# Out:
#                      PRICE
# COUNTRY SOURCE
# bra     android  34.387029
#         ios      34.222222
# can     android  33.330709
#         ios      33.951456
# deu     android  33.869888
#         ios      34.268817
# fra     android  34.312500
#         ios      32.776224
# tur     android  36.229437
#         ios      33.272727
# usa     android  33.760357
#         ios      34.371703

# %%
df.groupby(["COUNTRY", 'SOURCE', "SEX", "AGE"]).agg({"PRICE": "mean"}).head()
#COUNTRY, SOURCE, SEX, AGE kırılımında ortalama kazançlar nedir?
# Out:
#                                 PRICE
# COUNTRY SOURCE  SEX    AGE
# bra     android female 15   38.714286
#                        16   35.944444
#                        17   35.666667
#                        18   32.255814
#                        19   35.206897

# %%
agg_df = df.groupby(by=["COUNTRY", 'SOURCE', "SEX", "AGE"]).agg({"PRICE": "mean"}).sort_values("PRICE", ascending=False)
agg_df.head()
#Çıktıyı PRICE'a göre sıralayın
# Out:
#                             PRICE
# COUNTRY SOURCE  SEX    AGE
# bra     android male   46    59.0
# usa     android male   36    59.0
# fra     android female 24    59.0
# usa     ios     male   32    54.0
# deu     android female 36    49.0

# %%
agg_df = agg_df.reset_index()
agg_df.head() #Indekste yer alan isimleri değişken ismine çevirin
# Out:
#   COUNTRY   SOURCE     SEX  AGE  PRICE
# 0     bra  android    male   46   59.0
# 1     usa  android    male   36   59.0
# 2     fra  android  female   24   59.0
# 3     usa      ios    male   32   54.0
# 4     deu  android  female   36   49.0

# %%
#AGE değişkenini kategorik değişkene çeviriniz ve agg_df'e ekleyin
bins = [0, 18, 23, 30, 40, agg_df["AGE"].max()]
mylabels = ['0_18', '19_23', '24_30', '31_40', '41_' + str(agg_df["AGE"].max())]
agg_df["age_cat"] = pd.cut(agg_df["AGE"], bins, labels=mylabels)
agg_df.head()
# Out:
#   COUNTRY   SOURCE     SEX  AGE  PRICE age_cat
# 0     bra  android    male   46   59.0   41_66
# 1     usa  android    male   36   59.0   31_40
# 2     fra  android  female   24   59.0   24_30
# 3     usa      ios    male   32   54.0   31_40
# 4     deu  android  female   36   49.0   31_40

# %%
#Yeni seviye tabanlı müşterileri tanımlayınız ve veri setine değişken olarak ekleyin
agg_df.columns
agg_df["customers_level_based"] = ['_'.join(i).upper() for i in agg_df.drop(["AGE", "PRICE"], axis=1).values]
agg_df["customers_level_based"].value_counts()
agg_df.head()
# Out:
#   COUNTRY   SOURCE     SEX  AGE  PRICE age_cat  \
# 0     bra  android    male   46   59.0   41_66
# 1     usa  android    male   36   59.0   31_40
# 2     fra  android  female   24   59.0   24_30
# 3     usa      ios    male   32   54.0   31_40
# 4     deu  android  female   36   49.0   31_40
#
#                                customers_level_based
# 0  BRA_ANDROID_MALE_41_66_BRA_ANDROID_MALE_41_66_...
# 1  USA_ANDROID_MALE_31_40_USA_ANDROID_MALE_31_40_...
# 2  FRA_ANDROID_FEMALE_24_30_FRA_ANDROID_FEMALE_24...
# 3  USA_IOS_MALE_31_40_USA_IOS_MALE_31_40_USA_IOS_...
# 4  DEU_ANDROID_FEMALE_31_40_DEU_ANDROID_FEMALE_31...

# %%
#Yeni müşterileri (USA_ANDROID_MALE_0_18) segmentlere ayırın
agg_df["SEGMENT"] = pd.qcut(agg_df["PRICE"], 4, labels=["D", "C", "B", "A"])
agg_df.head(30)
agg_df.groupby("SEGMENT").agg({"PRICE": "mean"})
# Out:
#              PRICE
# SEGMENT
# D        27.302596
# C        32.933339
# B        35.436170
# A        41.434736
